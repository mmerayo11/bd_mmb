# %% [markdown]
# # PR0502: Composición multivista en Altair. Análisis de impactos de aves

# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from vega_datasets import data
import pandas as pd
import altair as alt
alt.data_transformers.disable_max_rows()
df = data.birdstrikes()
df['Flight_Date'] = pd.to_datetime(df['Flight_Date'], errors='coerce')
# Out:
# /tmp/ipykernel_4140/3128595391.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Flight_Date'] = pd.to_datetime(df['Flight_Date'], errors='coerce')

# %% [markdown]
# ## Ejercicio 1: Superposición de capas

# %%
base = alt.Chart(df).encode(
    x=alt.X('year(Flight_Date):T', title='Año'),
    y=alt.Y('count():Q', title='Número de Impactos')
)

lineas = base.mark_line(color='steelblue')
puntos = base.mark_point(color='darkred', tooltip=True)

chart1 = lineas + puntos
chart1.properties(title="Evolución anual de impactos de aves", width=600)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Ejercicio 2: Concatenación para un dashboard

# %%
gra_a = alt.Chart(df).mark_bar().encode(
    x='When__Time_of_day:N',
    y='count():Q',
    color='When__Time_of_day:N'
).properties(width=250, height=200)

gra_b = alt.Chart(df).mark_bar().encode(
    x='When__Phase_of_flight:N',
    y='count():Q',
    color='When__Phase_of_flight:N'
).properties(width=250, height=200)

gra_c = alt.Chart(df).mark_bar().encode(
    x='When__Phase_of_flight:N',
    y='count():Q',
    color='When__Phase_of_flight:N'
).properties(width=250, height=200)
