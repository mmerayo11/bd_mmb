# %% [markdown]
# ## Introducción a redis

# %%
# !pip install redis

# %%
import redis

r = redis.Redis(
    host='redis',
    port=6379,
    db=0,
    decode_responses=True
)

print(r.ping())
# Out:
# True

# %%
r.set("ciclo", "Especialización IA y Big Data")
# Out:
# True

# %%
print( r.get("ciclo"))
# Out:
# Especialización IA y Big Data
