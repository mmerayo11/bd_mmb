# %%
# !pip install redis

# %%
import redis
import json

r = redis.Redis(
    host='redis',
    port=6379,
    db=0,
    decode_responses=True
)

# %% [markdown]
# ## Función agregar pedido

# %%
def agregar_pedido(r, cliente, producto, esUrgente):
    nuevo_id = r.incr("contador_pedidos")
    id_pedido = f"pedido_{nuevo_id:03d}"

    pedido= {
        "id": id_pedido,
        "cliente": cliente,
        "producto": producto,
        "cantidad": 1,
        "urgente": esUrgente
    }

    pedido_json = json.dumps(pedido)

    elementos_en_lista = r.rpush("pedidos", pedido_json)

    print("Pedido añadido: ", pedido)

# %% [markdown]
# ## Función procesar pedido

# %%
def procesar_pedido(r):
    pedido_eliminado_json = r.lpop("pedidos", count=None)
    
    pedido_eliminado = json.loads(pedido_eliminado_json)

    print("Pedido eliminado: ", pedido_eliminado)

# %% [markdown]
# ## Prueba de funcionamiento

# %%
if __name__ == "__main__":
    #agregar_pedido(r, "Juan Pérez", "Portátil Lenovo", False)
    procesar_pedido(r)
# Out:
# Pedido eliminado:  {'id': 'pedido_015', 'cliente': 'Ana Rodríguez', 'producto': 'Teclado Mars Gaming', 'cantidad': 1, 'urgente': False}

# %% [markdown]
# ## Uso de las funciones

# %%
if __name__ == "__main__":
    #agregar_pedido(r,"Mario Merayo","Teléfono Xiaomi", False)
    #agregar_pedido(r,"Jesús Fernández","Aspiradora Bosch", False)
    #agregar_pedido(r,"Claudia Sánchez","Impresora Epson", False)
    #agregar_pedido(r,"Pablo López","Monitor HP", False)
    #agregar_pedido(r,"Ana Rodríguez","Teclado Mars Gaming", False)

    #print("Pedidos en lista: ", r.lrange("pedidos", 0, -1))

    #agregar_pedido(r,"Paco Cortés","Ratón SteelSeries", False)
    #agregar_pedido(r,"Marina Álvarez","Auriculares Astro", False)

    procesar_pedido(r)
    procesar_pedido(r)
    procesar_pedido(r)
    procesar_pedido(r)
    procesar_pedido(r)
    procesar_pedido(r)
    procesar_pedido(r)
# Out:
# Pedido eliminado:  {'id': 'pedido_016', 'cliente': 'Mario Merayo', 'producto': 'Teléfono Xiaomi', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_017', 'cliente': 'Jesús Fernández', 'producto': 'Aspiradora Bosch', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_018', 'cliente': 'Claudia Sánchez', 'producto': 'Impresora Epson', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_019', 'cliente': 'Pablo López', 'producto': 'Monitor HP', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_020', 'cliente': 'Ana Rodríguez', 'producto': 'Teclado Mars Gaming', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_021', 'cliente': 'Paco Cortés', 'producto': 'Ratón SteelSeries', 'cantidad': 1, 'urgente': False}
# Pedido eliminado:  {'id': 'pedido_022', 'cliente': 'Marina Álvarez', 'producto': 'Auriculares Astro', 'cantidad': 1, 'urgente': False}
